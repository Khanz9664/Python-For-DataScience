# %% [markdown]
# # Matplotlib
# <img src="https://i.imgur.com/5dPaHTw.png" width=400>

# %% [markdown]
# # Introduction to Matplotlib: From Basics to Advanced
# Matplotlib is a powerful Python library for creating static, interactive, and animated visualizations. It serves as a foundational tool in the data science ecosystem, offering flexibility and customization for a wide range of plotting needs. From simple line graphs to complex 3D visualizations, Matplotlib enables users to communicate data insights effectively.
#
# Why Use Matplotlib?
# Customizable: Fine-tune every element of your plot, from colors to labels.
# Versatile: Create a variety of visualizations like line plots, bar charts, scatter plots, and more.
# Seamless Integration: Works well with libraries like NumPy, Pandas, and Seaborn for enhanced functionality.
# Data Storytelling: Use animations and interactivity to bring your data to life.
#
# What Will You Learn?
# This notebook is designed to take you from the basics of plotting to advanced concepts in Matplotlib, including:
#
# Basic Plotting: Line graphs, scatter plots, bar charts, and more.
# Customization: Learn how to add annotations, legends, and style your plots.
# Subplots and Layouts: Work with multiple plots in a single figure.
# Statistical Visualizations: Create histograms, boxplots, and density plots.
# 3D Visualizations: Explore 3D plotting for multidimensional data.
# Animations and Interactivity: Add motion and interactivity to your visualizations.
# Practical Use Cases: Apply Matplotlib to real-world data science problems.
#
# Who Is This For?
# Beginners: Looking for a hands-on introduction to Matplotlib.
# Intermediate Users: Wanting to enhance their visualization skills.
# Data Scientists: Interested in leveraging Matplotlib for data analysis and storytelling.
#
# Prerequisites
# Before diving into this notebook, ensure you have:
#
# A basic understanding of Python.
# Familiarity with libraries like NumPy and Pandas (helpful but not mandatory).
#
# Let’s start by exploring the basics of Matplotlib and gradually build towards mastering this essential visualization tool!

# %% [markdown]
# #
# ## 1. Basics of Matplotlib
# ### 1.1 Importing Matplotlib and Plotting a Simple Line Graph

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #
# ### Simple line plot

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y, label="y = 2x")# Plots the data points defined by x and y on a 2D graph. The label argument sets the legend entry for the line.
plt.title("Simple Line Graph")# Sets the title of the graph.
plt.xlabel("X-axis")# Labels the x-axis.
plt.ylabel("Y-axis")# Labels the y-axis.
plt.legend()# Displays a legend for the graph, using the label defined in plt.plot.
plt.show()# Renders and displays the graph.

# %% [markdown]
# #
# ## 2. Customizing Plots
# ### 2.1 Adding Styles and Colors

# %%
# Using styles
plt.style.use('seaborn-darkgrid')

# Customizing line styles and colors
plt.plot(x, y, color='blue', linestyle='--', marker='o', label="y = 2x")
plt.title("Styled Line Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_11597/357175822.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %% [markdown]
# #
# ### 2.2 Adding Annotations

# %%
plt.plot(x, y, marker='o')
plt.title("Line Graph with Annotation")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Annotating a specific point
plt.annotate('Peak Point', xy=(5, 10), xytext=(4, 9),
             arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.show()

# %% [markdown]
# #
# ## 3. Multiple Plots and Subplots
# ### 3.1 Multiple Plots in a Single Figure

# %%
x1 = [1, 2, 3, 4, 5]
y1 = [1, 4, 9, 16, 25]

x2 = [1, 2, 3, 4, 5]
y2 = [2, 4, 6, 8, 10]

plt.plot(x1, y1, label="y = x^2")
plt.plot(x2, y2, label="y = 2x")
plt.title("Multiple Lines in One Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.show()

# %% [markdown]
# #
# ### 3.2 Creating Subplots

# %%
# Creating subplots
fig, axs = plt.subplots(2, 1, figsize=(8, 6))

# First subplot
axs[0].plot(x1, y1, color='red', label='y = x^2')
axs[0].set_title("First Subplot")
axs[0].legend()

# Second subplot
axs[1].plot(x2, y2, color='blue', label='y = 2x')
axs[1].set_title("Second Subplot")
axs[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# #
# ## 4. Advanced Plot Types
# ### 4.1 Bar Charts

# %%
categories = ['A', 'B', 'C', 'D']
values = [3, 7, 8, 5]

plt.bar(categories, values, color='green')
plt.title("Bar Chart")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# #
# ### 4.2 Scatter Plots

# %%
import numpy as np

x = np.random.rand(50)
y = np.random.rand(50)
colors = np.random.rand(50)
sizes = 500 * np.random.rand(50)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='viridis')
plt.colorbar()
plt.title("Scatter Plot")
plt.show()

# %% [markdown]
# #
# ## 5. 3D Plotting

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

# 3D surface plot
ax.plot_surface(X, Y, Z, cmap='viridis')
ax.set_title("3D Surface Plot")
plt.show()

# %% [markdown]
# #
# ## 6. Plot Annotations and Legends
# ### 6.1 Adding Gridlines and Legends

# %%
plt.plot(x1, y1, label="y = x^2")
plt.plot(x2, y2, label="y = 2x")
plt.title("Graph with Grid and Legends")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# #
# ## 7. Animations

# %%
#This will enable interactive plots and allow the animation to display in the notebook.
# %matplotlib notebook

# %%
from matplotlib.animation import FuncAnimation

fig, ax = plt.subplots()
x, y = [], []

line, = ax.plot([], [], 'r-')

def init():
    ax.set_xlim(0, 10)
    ax.set_ylim(0, 100)
    return line,

def update(frame):
    x.append(frame)
    y.append(frame**2)
    line.set_data(x, y)
    return line,

ani = FuncAnimation(fig, update, frames=range(10), init_func=init, blit=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #
# ## 8. Saving and Exporting Plots

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.plot(x, y, label="Sample Plot")
plt.title("Save This Plot")
plt.legend()

# Save as PNG
plt.savefig('plot.png', dpi=300)

plt.show()

# %% [markdown]
# #
# ## 9. Advanced Customizations
# ### 9.1 Custom Ticks and Labels

# %%
import numpy as np

# %%
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

plt.plot(x, y)
plt.xticks([0, np.pi/2, np.pi, 3*np.pi/2, 2*np.pi], 
           ['0', 'π/2', 'π', '3π/2', '2π'])
plt.yticks([-1, 0, 1], ['Low', 'Zero', 'High'])
plt.title("Custom Ticks and Labels")
plt.show()

# %% [markdown]
# #
# ## 10. Statistical Visualizations
# ### 10.1 Histograms with Density Plot

# %%
data = np.random.randn(1000)

plt.hist(data, bins=30, density=True, alpha=0.5, color='blue', label='Histogram')
plt.title("Histogram with Density Plot")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %% [markdown]
# #
# ### 10.2 Boxplots

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

plt.boxplot(data, vert=True, patch_artist=True, labels=['A', 'B', 'C'])
plt.title("Boxplot Example")
plt.xlabel("Category")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# #
# ## 11. Seaborn Integration (Enhanced Visualization)

# %%
import seaborn as sns

# %%
data = np.random.randn(1000)

sns.histplot(data, kde=True, color="purple")
plt.title("Histogram with KDE (Seaborn)")
plt.show()

# %% [markdown]
# #
# ## 12. Working with Dates

# %%
import matplotlib.dates as mdates
import pandas as pd

# %%
# Generate a time series
dates = pd.date_range("2023-01-01", periods=10)
values = np.random.randint(1, 10, size=10)

plt.figure(figsize=(10, 5))
plt.plot(dates, values, marker='o')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator())
plt.title("Time Series Data")
plt.xlabel("Date")
plt.ylabel("Value")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #
# ## 13.Adding Images to Plots

# %%
import matplotlib.image as mpimg

img = mpimg.imread('cat.jpg')  # Replace with your image file
plt.imshow(img)
plt.axis('off')  # Turn off axis
plt.title("Image")
plt.show()

# %% [markdown]
# #
# ## 14.Heatmaps

# %%
data = np.random.rand(6, 6)

plt.imshow(data, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.title("Heatmap")
plt.show()

# %% [markdown]
# #
# ## 15. Animations (Advanced)
# ### 15.1.Animated Scatter Plot

# %%
import matplotlib.animation as animation

fig, ax = plt.subplots()
x, y = [], []
sc = ax.scatter([], [], s=100)

def init():
    ax.set_xlim(0, 10)
    ax.set_ylim(0, 10)
    return sc,

def update(frame):
    x.append(np.random.rand())
    y.append(np.random.rand())
    sc.set_offsets(np.c_[x, y])
    return sc,

ani = animation.FuncAnimation(fig, update, frames=20, init_func=init, blit=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #
# ## 16.Multi-Axis and Twin Axes
# ### 16.1 Secondary Y-axis

# %%
fig, ax1 = plt.subplots()

x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

ax1.plot(x, y1, 'b-')
ax1.set_xlabel('X-axis')
ax1.set_ylabel('Sin', color='blue')

ax2 = ax1.twinx()
ax2.plot(x, y2, 'r--')
ax2.set_ylabel('Cos', color='red')

plt.title("Twin Axes Example")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #
# ## 17.3D Plotting (Advanced)
# ### 17.1 3D Wireframe Plot

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

ax.plot_wireframe(X, Y, Z, color='green')
plt.title("3D Wireframe")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #
# ## 18. Styling and Themes
# ### 18.1 Predefined Styles

# %%
print(plt.style.available)  # List all styles
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
# Use a style
plt.style.use('ggplot')
plt.plot(x, y1, label="Sin")
plt.plot(x, y2, label="Cos")
plt.title("Styled Plot (ggplot)")
plt.legend()
plt.show()
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #
# ### 18.2 Customizing Figure Size

# %%
plt.figure(figsize=(12, 6))
plt.plot(x, y1, label="Sin")
plt.plot(x, y2, label="Cos")
plt.title("Custom Figure Size")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# #
# ## 19. Interactivity
# ### 19.1 Interactive Widgets with mpl_toolkits

# %%
from mpl_toolkits.mplot3d import Axes3D
from ipywidgets import interact

def plot_3d(angle):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.view_init(elev=30, azim=angle)
    ax.plot_wireframe(X, Y, Z)
    plt.show()

interact(plot_3d, angle=(0, 360, 10))
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(IntSlider(value=180, description='angle', max=360, step=10), Output()), _dom_classes=('w…
# <function __main__.plot_3d(angle)>
